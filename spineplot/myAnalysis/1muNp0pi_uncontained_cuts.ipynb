# %%
import toml
import os
import sys
workspace_root = os.getcwd()  
sys.path.insert(0, workspace_root + "/..")
from analysis import Analysis

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "1muNp0pi_uncontained_cuts"
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained_cuts.root'

# %%
# Delta p_T plots
analysis = Analysis(ana_directory + '/dpT/dpT.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'true_dpT_lp_genie'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
# ...

# %%
analysis = Analysis(ana_directory + '/efficiency.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: signal
# ...
# Setting weight for signal to 1.00e+00

# %%
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_contained_type.root'

# %%
analysis = Analysis(ana_directory + '/nu_energy/nu_energy.toml', data_file)
analysis.run(close_figs=False)
# Out:
# Found NaN category in Sample `mc` with 774 occurrence(s). Masking NaNs...
#
# ...
# Processing systematics for sample: mc
# ...
# Setting weight for mc to 1.00e+00

# %%
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained_type.root'

# %%
analysis = Analysis(ana_directory + '/nu_energy/nu_energy.toml', data_file)
analysis.run(close_figs=False)
# Out:
# Found NaN category in Sample `mc` with 2529 occurrence(s). Masking NaNs...
#
# ...
# Processing systematics for sample: mc
# ...
# Setting weight for mc to 1.00e+00

# %%
import uproot
f = uproot.open('/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained_systematics.root')
print(f.keys())
print(f['events/full/selected'].num_entries)
# Out:
# ['variations;1', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE_2d;3', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE_2d;2', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE_2d;1', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE_2d;3', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE_2d;2', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE_2d;1', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE_2d;3', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE_2d;2', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE_2d;1', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA4CCQE_2d;3', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZExpA4CCQE_2d;2', 'variations/reco_leading_muon_ke_GENIEReWeight_SBN_v1_multisigma_ZEx
# ...
