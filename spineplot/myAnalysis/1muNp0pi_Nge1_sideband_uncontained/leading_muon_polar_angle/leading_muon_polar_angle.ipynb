# %%
import toml
import os
import sys
workspace_root = os.getcwd()
sys.path.insert(0, workspace_root + "/../../..")
from analysis import Analysis

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "../../1muNp0pi_Nge1_sideband_uncontained"
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_ppfx.root'

# %%
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle.toml', data_file)
analysis.run(close_figs=False)

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# File and tree
fpath = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_gundam_withPCA.root'

with uproot.open(fpath) as f:
    tree = f['events/full/sideband']
    reco_cos_polar   = tree['reco_leading_muon_polar_angle_cos'].array(library='np')
    true_cos_polar   = tree['true_leading_muon_polar_angle_cos'].array(library='np')
    true_category    = tree['true_category'].array(library='np')
    muon_contained   = tree['reco_leading_muon_containment'].array(library='np')

# Signal categories
signal_mask = np.isin(true_category, [0, 1, 3, 4])

# Valid kinematics mask
valid_mask = (
    np.isfinite(true_cos_polar) &
    np.isfinite(reco_cos_polar) &
    (np.abs(reco_cos_polar) <= 1.5) &
    (np.abs(true_cos_polar) <= 1.5)
)

# Compute absolute residual
abs_residual = reco_cos_polar - true_cos_polar

# Combined, contained, exiting masks
combined_mask  = signal_mask & valid_mask
contained_mask = signal_mask & valid_mask & (muon_contained == 1)
exiting_mask   = signal_mask & valid_mask & (muon_contained == 0)

# Binning
x_bins = np.linspace(-1, 1, 21)
y_bins = np.linspace(-0.5, 0.5, 41)

# Plot
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
plt.subplots_adjust(left=0.07, right=0.98, top=0.88, bottom=0.12, wspace=0.35)

titles = [
    r'Contained + Exiting $\mu^\pm$',
    r'Contained $\mu^\pm$',
    r'Exiting $\mu^\pm$'
]
masks = [combined_mask, contained_mask, exiting_mask]

for ax, mask, title in zip(axes, masks, titles):
    h, xedges, yedges = np.histogram2d(
        true_cos_polar[mask],
        abs_residual[mask],
        bins=[x_bins, y_bins]
    )

    im = ax.imshow(
        h.T,
        extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],
        aspect='auto',
        origin='lower',
        norm=mcolors.LogNorm(vmin=1, vmax=h.max()),
        cmap='magma'
    )

    ax.axhline(y=0, color='white', linestyle='--', linewidth=1.5, alpha=0.7)
    ax.set_xlabel(r'True $\cos(\theta_\mu)$ polar', fontsize=12, fontweight='bold')
    ax.set_ylabel(r'$\cos(\theta_\mu)^{\mathrm{reco}}_\mathrm{pol} - \cos(\theta_\mu)^{\mathrm{true}}_\mathrm{pol}$',
                  fontsize=12, fontweight='bold')
    ax.set_title(title, fontsize=13, fontweight='bold')
    ax.tick_params(axis='both', which='major', labelsize=11, size=6, width=1.5)

    cbar = plt.colorbar(im, ax=ax)
    cbar.set_label('Signal Events', fontsize=11, fontweight='bold')
    cbar.ax.tick_params(labelsize=10)

plt.savefig('pdf/leading_muon_polar_angle_resolution_vs_true_cos_polar.pdf', bbox_inches='tight', dpi=150)
plt.show()

# %%
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle_xSecUncertainty.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading muon polar angle cross-section uncertainties expanded
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle_xSecUncertainty_Exp.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading muon polar angle flux uncertainties
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle_FluxUncertainty.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading muon polar angle flux uncertainties expanded
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle_FluxUncertainty_Exp.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading muon polar angle detector uncertainties
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle_DetectorUncertainty.toml', data_file)
analysis.run(close_figs=False)
