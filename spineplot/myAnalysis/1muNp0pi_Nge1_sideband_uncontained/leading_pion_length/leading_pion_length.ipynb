# %%
import toml
import os
import sys
workspace_root = os.getcwd()
sys.path.insert(0, workspace_root + "/../../..")
from analysis import Analysis

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "../../1muNp0pi_Nge1_sideband_uncontained"
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_ppfx.root'

# %%
analysis = Analysis(ana_directory + '/leading_pion_length/leading_pion_length.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
# --Systematic(statistical, None)--
# 	Fractional uncertainty: 2.00%
# --Systematic(stats, Stat.)--
# 	Fractional uncertainty: 2.00%
# --Systematic(MC_total, All Systematics (No G4))--
# 	Fractional uncertainty: 2.00%
#
# ...
# Processing systematics for sample: mc_nonmatched
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
#
# ...
# Processing systematics for sample: offbeam
# ...
#
# ...
# Processing systematics for sample: rock
# ...
# Setting weight for mc to 3.29e-02
# Setting weight for mc_nonmatched to 3.29e-02
# Setting weight for onbeam to 1.00e+00
# Setting weight for offbeam to 9.53e-02
# Setting weight for rock to 1.38e+00
# Fractional - Min: 2.71%, Max: 2.77%
# Fractional - Min: 2.75%, Max: 3.00%
# ...

# %%
# Leading pion length cross-section uncertainties
analysis = Analysis(ana_directory + '/leading_pion_length/leading_pion_length_xSecUncertainty.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading pion length cross-section uncertainties expanded
analysis = Analysis(ana_directory + '/leading_pion_length/leading_pion_length_xSecUncertainty_Exp.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading pion length flux uncertainties
analysis = Analysis(ana_directory + '/leading_pion_length/leading_pion_length_FluxUncertainty.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading pion length flux uncertainties expanded
analysis = Analysis(ana_directory + '/leading_pion_length/leading_pion_length_FluxUncertainty_Exp.toml', data_file)
analysis.run(close_figs=False)

# %%
# Leading pion length detector uncertainties
analysis = Analysis(ana_directory + '/leading_pion_length/leading_pion_length_DetectorUncertainty.toml', data_file)
analysis.run(close_figs=False)
